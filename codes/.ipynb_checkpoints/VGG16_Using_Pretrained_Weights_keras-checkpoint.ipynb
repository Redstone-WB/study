# %% [markdown]
# # 20191006, vgg16, using pretrained weights, keras
#
# ## 마지막 layer인 fully connected layer만 학습시킴. 그 전 weights는 pretrain된 것 사용! (keras 제공)

# %% [markdown]
# ## Below are codes from lazyprogrammer

# %%
#!pip3 install sklearn
# Out:
# ...
#      |████████████████████████████████| 10.5MB 134kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 296kB 166kB/s eta 0:00:01
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1316 sha256=f58eca60f7645346f5d3ce38c4e886c732c28202b57145ad50802a51e27cbfe0
#   Stored in directory: /Users/sktelecom/Library/Caches/pip/wheels/76/03/bb/589d421d27431bcd2c6da284d5f2286c8e3b2ea3cf1594c074
# Successfully built sklearn
# ...

# %%
#!pip3 install --upgrade future
# Out:
# Requirement already up-to-date: future in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (0.17.1)

# %%
# https://deeplearningcourses.com/c/advanced-computer-vision
# https://www.udemy.com/advanced-computer-vision
from __future__ import print_function, division
from builtins import range, input
# Note: you may need to update your version of future
# sudo pip install -U future

from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt

from glob import glob
# Out:
# Using TensorFlow backend.

# %%
# re-size all the images to this
IMAGE_SIZE = [100, 100] # feel free to change depending on dataset

# training config:
epochs = 5
batch_size = 32

# https://www.kaggle.com/paultimothymooney/blood-cells
# train_path = '../large_files/blood_cell_images/TRAIN'
# valid_path = '../large_files/blood_cell_images/TEST'

# https://www.kaggle.com/moltean/fruits
# train_path = '../large_files/fruits-360/Training'
# valid_path = '../large_files/fruits-360/Validation'
train_path = '/Users/sktelecom/Documents/GitHub/study/datasets/fruits-360_dataset/fruits-360/Training'
valid_path = '/Users/sktelecom/Documents/GitHub/study/datasets/fruits-360_dataset/fruits-360/Test'

# useful for getting number of files
image_files = glob(train_path + '/*/*.jp*g')
valid_image_files = glob(valid_path + '/*/*.jp*g')

# %%
#!pip3 install imageio

# %% [markdown]
# ## Imread

# %%
from IPython.display import display
from PIL import Image
#import imageio

# %%
#!pip3 install --upgrade tensorflow keras numpy pandas sklearn pillow
# Out:
# Uninstalling Pillow-6.2.0:
#   Successfully uninstalled Pillow-6.2.0

# %%
#!pip3 install pillow

# %%
# useful for getting number of classes
folders = glob(train_path + '/*')


# look at an image for fun
file = np.random.choice(image_files)
plt.imshow(image.load_img(file))
print(file)
plt.show()
# Out:
# /Users/sktelecom/Documents/GitHub/study/datasets/fruits-360_dataset/fruits-360/Training/Grapefruit Pink/2_100.jpg

# %%
# add preprocessing layer to the front of VGG
vgg = VGG16(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)

# don't train existing weights, 기존 weights train하지 않는다는 것 여기서 명시!
for layer in vgg.layers:
  layer.trainable = False

# our layers - you can add more if you want  여기서 custom layer를 추가하는 것!! vgg.ouput을 input으로 받는다.
x = Flatten()(vgg.output)     
# x = Dense(1000, activation='relu')(x)
prediction = Dense(len(folders), activation='softmax')(x)


# create a model object
model = Model(inputs=vgg.input, outputs=prediction)

# %%
# view the structure of the model, 모델에 포함된 모든 layers를 보여 준다.
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         (None, 100, 100, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 100, 100, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 100, 100, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 50, 50, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 50, 50, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 50, 50, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 25, 25, 128)       0
# ...

# %%
# tell the model what cost and optimization method to use : loss function으로는 뭐 쓸지, optimizer는 뭐 쓸지, gradient descent 할 때 어떤 metric 계산을 할 지..
model.compile(
  loss='categorical_crossentropy',
  optimizer='rmsprop',
  metrics=['accuracy']
)

# %%
# create an instance of ImageDataGenerator
gen = ImageDataGenerator(
  rotation_range=20,
  width_shift_range=0.1,
  height_shift_range=0.1,
  shear_range=0.1,
  zoom_range=0.2,
  horizontal_flip=True,
  vertical_flip=True,
  preprocessing_function=preprocess_input
)

# %%
# test generator to see how it works and some other useful things, 

# get label mapping for confusion matrix plot later
test_gen = gen.flow_from_directory(valid_path, target_size=IMAGE_SIZE) # target_size를 정하여, Image resizing이 가능하다.
print(test_gen.class_indices)
labels = [None] * len(test_gen.class_indices) #category들이 많으니까, for loop 이용해서 labels에 dictionary를 만들어 준다.
for k, v in test_gen.class_indices.items(): #k for key, v for value
  labels[v] = k
# Out:
# Found 20622 images belonging to 120 classes.
# ...

# %%
#

# %%
# should be a strangely colored image (due to VGG weights being BGR). 이건 library 경향성임. RGB가 아니라 BGR로 cafe에서 처리하기 때문.. 
# BGR -> RGB 는 keras에서 제공하는 preprocess function 이용
for x, y in test_gen:   #x는 이미지(숫자로 이루어진 tensor), y는 label (matrix, one-hot encoded)
  print("min:", x[0].min(), "max:", x[0].max())  #숫자 보면 알 수 있음.. RGB는 0~555 사이인데, BGR은 아님.
  plt.title(labels[np.argmax(y[0])])
  plt.imshow(x[0])
  plt.show()
  break
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# min: -71.02317 max: 151.061

# %%
# create generators
train_generator = gen.flow_from_directory(
  train_path,
  target_size=IMAGE_SIZE,
  shuffle=True,
  batch_size=batch_size,
)
valid_generator = gen.flow_from_directory(
  valid_path,
  target_size=IMAGE_SIZE,
  shuffle=True,
  batch_size=batch_size,
)
# Out:
# Found 60498 images belonging to 120 classes.
# Found 20622 images belonging to 120 classes.

# %%
epochs = 1
# fit the model, keras 의 model.fit은 numpy array들을 input으로 받지만, model.fit_generator은 generator을 input으로도 받을 수 있음!
r = model.fit_generator(
  train_generator,
  validation_data=valid_generator,
  epochs=epochs,
  steps_per_epoch=len(image_files) // batch_size,
  validation_steps=len(valid_image_files) // batch_size,
)
# Out:
# Epoch 1/1
# 1889/1890 [============================>.] - ETA: 0s - loss: 0.5250 - accuracy: 0.9549
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-f8c2804acfc7> in <module>
#       6   epochs=epochs,
#       7   steps_per_epoch=len(image_files) // batch_size,
# ----> 8   validation_steps=len(valid_image_files) // batch_size,
#       9 )
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ...

# %%
##원래같으면 confusion matrix 만들기 위해, scikit learn 패키지 쓰면 되지만,,
##predictions과 실제 targets가 맞는지 list로 확인하기 위함. (순서대로)

def get_confusion_matrix(data_path, N):
  # we need to see the data in the same order
  # for both predictions and targets
  print("Generating confusion matrix", N)
  predictions = []
  targets = []
  i = 0
  for x, y in gen.flow_from_directory(data_path, target_size=IMAGE_SIZE, shuffle=False, batch_size=batch_size * 2):
    i += 1
    if i % 50 == 0:
      print(i)
    p = model.predict(x)
    p = np.argmax(p, axis=1)
    y = np.argmax(y, axis=1)
    predictions = np.concatenate((predictions, p))
    targets = np.concatenate((targets, y))
    if len(targets) >= N:
      break

  cm = confusion_matrix(targets, predictions)
  return cm


cm = get_confusion_matrix(train_path, len(image_files))
print(cm)
valid_cm = get_confusion_matrix(valid_path, len(valid_image_files))
print(valid_cm)
# Out:
# Generating confusion matrix 60498
# Found 60498 images belonging to 120 classes.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-cda511f22e36> in <module>
#      22
#      23
# ---> 24 cm = get_confusion_matrix(train_path, len(image_files))
#      25 print(cm)
#      26 valid_cm = get_confusion_matrix(valid_path, len(valid_image_files))
#
# <ipython-input-9-cda511f22e36> in get_confusion_matrix(data_path, N)
#      10     if i % 50 == 0:
#      11       print(i)
# ---> 12     p = model.predict(x)
#      13     p = np.argmax(p, axis=1)
#      14     y = np.argmax(y, axis=1)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1460                                             verbose=verbose,
# ...

# %%
# plot some data

# loss
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.legend()
plt.show()

# accuracies
plt.plot(r.history['acc'], label='train acc')
plt.plot(r.history['val_acc'], label='val acc')
plt.legend()
plt.show()

from util import plot_confusion_matrix
plot_confusion_matrix(cm, labels, title='Train confusion matrix')
plot_confusion_matrix(valid_cm, labels, title='Validation confusion matrix')
